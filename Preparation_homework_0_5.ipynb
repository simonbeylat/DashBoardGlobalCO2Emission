# %% [markdown]
# # Preparation homework 0.5
# Simon Beylat

# %% [markdown]
# ##Exploration of the Data

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

import plotly
import plotly.express as px 
import plotly.graph_objects as go 
import plotly.figure_factory as ff

# %%
df = pd.read_csv('data/GCB2020v18_MtCO2_flat.csv',sep=',',encoding='latin-1')

# %%
df
# Out:
#            Country ISO 3166-1 alpha-3  Year  ...     Flaring       Other  Per Capita
# 0      Afghanistan                AFG  1750  ...         NaN         NaN         NaN
# 1      Afghanistan                AFG  1751  ...         NaN         NaN         NaN
# 2      Afghanistan                AFG  1752  ...         NaN         NaN         NaN
# 3      Afghanistan                AFG  1753  ...         NaN         NaN         NaN
# 4      Afghanistan                AFG  1754  ...         NaN         NaN         NaN
# ...            ...                ...   ...  ...         ...         ...         ...
# 61285        World                WLD  2015  ...  362.053077  117.635368    4.771059
# 61286        World                WLD  2016  ...  371.409053  111.799798    4.718691
# 61287        World                WLD  2017  ...  403.984248  113.151838    4.729334
# 61288        World                WLD  2018  ...  429.495561  115.121000    4.772543
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61290 entries, 0 to 61289
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             61290 non-null  object
#  1   ISO 3166-1 alpha-3  59670 non-null  object
#  2   Year                61290 non-null  int64
#  3   Total               25949 non-null  float64
#  4   Coal                20888 non-null  float64
#  5   Oil                 20853 non-null  float64
#  6   Gas                 20756 non-null  float64
#  7   Cement              20545 non-null  float64
#  8   Flaring             20688 non-null  float64
#  9   Other               1290 non-null   float64
#  10  Per Capita          16020 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 5.1+ MB

# %% [markdown]
# ##First Plot on Global

# %% [markdown]
# ###1D plot

# %%
df_Golbal = df.loc[df.Country == 'World']

# %%
fig = go.Figure([go.Bar(y=df_Golbal["Per Capita"])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d191de75-50eb-47be-95a4-557023e5f01e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d191de75-50eb-47be-95a4-557023e5f01e")) {
#                     Plotly.newPlot(
#                         'd191de75-50eb-47be-95a4-557023e5f01e',
# ...

# %%
fig = go.Figure([go.Bar(y=df_Golbal["Coal"])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1add90cf-0454-45bd-a4d3-fa524a44e5ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1add90cf-0454-45bd-a4d3-fa524a44e5ea")) {
#                     Plotly.newPlot(
#                         '1add90cf-0454-45bd-a4d3-fa524a44e5ea',
# ...

# %%
fig = go.Figure([go.Bar(y=df_Golbal["Total"])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aa952dcc-1ed5-43b0-8aa1-c38a4c2c07f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa952dcc-1ed5-43b0-8aa1-c38a4c2c07f9")) {
#                     Plotly.newPlot(
#                         'aa952dcc-1ed5-43b0-8aa1-c38a4c2c07f9',
# ...

# %% [markdown]
# ###2D plot

# %%
fig = px.bar(df_Golbal, x="Year", y="Total")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="878d210b-853d-425f-9110-e242ed07f48d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("878d210b-853d-425f-9110-e242ed07f48d")) {
#                     Plotly.newPlot(
#                         '878d210b-853d-425f-9110-e242ed07f48d',
# ...

# %%
fig = go.Figure([go.Bar(x=df.loc[df.Year == 2019]["Total"], y=df.loc[df.Year == 2019]["Per Capita"])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3c5425c8-57dd-4e37-b333-71fc51a09cba" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3c5425c8-57dd-4e37-b333-71fc51a09cba")) {
#                     Plotly.newPlot(
#                         '3c5425c8-57dd-4e37-b333-71fc51a09cba',
# ...

# %%
element = ['Saudi Arabia','Japan','Indonesia','Mexico','Turkey','Indonesia','Italy','South Africa','South Korea']

# %%
len(element)
# Out:
# 9

# %%
df_2019=df_2019.assign(good=0)
for country in element:
  df_2019.loc[df_2019.Country == country,'good']=1

# %%
fig = px.scatter(df_2019.loc[df_2019.good == 1], x="Per Capita", y="Country",
                 hover_name="Country",color = 'Country',size='Per Capita',size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a59a8932-1b3b-47bd-9d45-38ba5d2dce19" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a59a8932-1b3b-47bd-9d45-38ba5d2dce19")) {
#                     Plotly.newPlot(
#                         'a59a8932-1b3b-47bd-9d45-38ba5d2dce19',
# ...

# %%
Total = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Total'],
    name= 'Total'
)
Coal = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Coal'],
    name= 'Coal'
)
Oil = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Oil'],
    name= 'Oil'
)
Gas = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Gas'],
    name= 'Gas'
)
Cement = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Cement'],
    name= 'Cement'
)
Flaring = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Flaring'],
    name= 'Flaring'
)
Other = go.Scatter(
    x = df_Golbal['Year'],
    y = df_Golbal['Other'],
    name= 'Other'
)
data = go.Data([Total, Coal, Oil, Gas, Cement,Flaring,Other])

layout = go.Layout(
    title = "Global CO2 Emission",
    xaxis = go.XAxis(
        title = "Year",
    ),
    yaxis = go.YAxis(
        title = "CO2 Emission",
    )
)

figure = go.Figure(data=data, layout=layout)
plotly.offline.iplot(figure)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:40: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:550: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:578: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
df.loc[df.Year == 2019]
# Out:
#                        Country ISO 3166-1 alpha-3  ...    Other  Per Capita
# 269                Afghanistan                AFG  ...      NaN    0.281804
# 539                    Albania                ALB  ...      NaN    1.936541
# 809                    Algeria                DZA  ...      NaN    3.988266
# 1079                   Andorra                AND  ...      NaN    6.099075
# 1349                    Angola                AGO  ...      NaN    1.194657
# ...                        ...                ...  ...      ...         ...
# 60209                    Yemen                YEM  ...      NaN    0.351659
# 60479                   Zambia                ZMB  ...      NaN    0.376266
# 60749                 Zimbabwe                ZWE  ...      NaN    0.708362
# 61019  International Transport                XIT  ...      NaN         NaN
# 61289                    World                WLD  ...  115.121    4.724384
#
# [227 rows x 11 columns]

# %%
country ='World'

# %%
Total = go.Scatter(
    x = df.loc[df.Country == country]['Year'],
    y = df.loc[df.Country == country]['Per Capita'],
    name= 'Total'
)
data = go.Data([Total])

layout = go.Layout(
    title = "Global CO2 Emission per capita",
    xaxis = go.XAxis(
        title = "Year",
    ),
    yaxis = go.YAxis(
        title = "CO2 Emission per capita",
    )
)

figure = go.Figure(data=data, layout=layout)
plotly.offline.iplot(figure)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:40: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:550: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:578: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
Coal = go.Bar(
    x = ['Coal'],
    y = df.loc[(df.Year == 2019) & (df.Country == country)]['Coal'],
    name= 'Coal'
)
Oil = go.Bar(
    x = ['Oil'],
    y = df.loc[(df.Year == 2019) & (df.Country == country)]['Oil'],
    name= 'Oil'
)
Gas = go.Bar(
    x = ['Gas'],
    y = df.loc[(df.Year == 2019) & (df.Country == country)]['Gas'],
    name= 'Gas'
)
Cement = go.Bar(
    x = ['Cement'],
    y = df.loc[(df.Year == 2019) & (df.Country == country)]['Cement'],
    name= 'Cement'
)
Flaring = go.Bar(
    x = ['Flaring'],
    y = df.loc[(df.Year == 2019) & (df.Country == country)]['Flaring'],
    name= 'Flaring'
)
Other = go.Bar(
    x = ['Other'],
    y = df.loc[(df.Year == 2019) & (df.Country == country)]['Other'],
    name= 'Other'
)
data = go.Data([Coal, Oil, Gas, Cement,Flaring,Other])

layout = go.Layout(
    title = "Global CO2 Emission",
    xaxis = go.YAxis(
        title = "Fossil fuels",
    ),

    yaxis = go.YAxis(
        title = "CO2 Emission",
    )
)

figure = go.Figure(data=data, layout=layout)
plotly.offline.iplot(figure)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:40: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
#
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:578: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
# ...

# %%
fig = px.line(df_Golbal, x="Year", y=df_Golbal['Per Capita'])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f494c5ac-dedb-4984-9cf7-462f4ff3eed8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f494c5ac-dedb-4984-9cf7-462f4ff3eed8")) {
#                     Plotly.newPlot(
#                         'f494c5ac-dedb-4984-9cf7-462f4ff3eed8',
# ...

# %% [markdown]
# ## 2D plot with post-processing

# %%
df.loc[df.Country == 'USA', 'Country'] = 'United States'

# %%
df_continent = pd.read_csv('data/Countries-Continents.csv',encoding='latin-1')

# %%
df2 = pd.merge(
  df, 
  df_continent, 
  left_on='Country', 
  right_on='Country',
  how="left",
)

# %%
df_merged =df2.loc[ df2.Continent.isin(['Asia', 'Europe', 'Africa','North America', 'South America','Oceania'])]

# %%
fig = px.bar(df_merged, x='Continent', y='Total',animation_frame='Year',hover_name='Country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="49a828fb-06aa-4748-849d-93f9c1a1d641" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49a828fb-06aa-4748-849d-93f9c1a1d641")) {
#                     Plotly.newPlot(
#                         '49a828fb-06aa-4748-849d-93f9c1a1d641',
# ...

# %%
fig = px.line(df_merged,x=df_merged['Year'],y=df_merged['Total'],line_group='Continent',color='Continent')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="38864053-ca3c-43b3-b7cb-95015260de2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("38864053-ca3c-43b3-b7cb-95015260de2e")) {
#                     Plotly.newPlot(
#                         '38864053-ca3c-43b3-b7cb-95015260de2e',
# ...

# %%
df_without_Total = df.loc[df.Country != 'Global']

# %%
fig = px.choropleth(df_without_Total, locations="ISO 3166-1 alpha-3",
                    color="Per Capita",
                    hover_name="Country", 
                    animation_frame = "Year",
                    color_continuous_scale='fall'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87464905-9516-47ef-8fd2-1432fcc46513" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87464905-9516-47ef-8fd2-1432fcc46513")) {
#                     Plotly.newPlot(
#                         '87464905-9516-47ef-8fd2-1432fcc46513',
# ...

# %%
np.max(df.Total)
# Out:
# 36441.387575

# %%
np.mean(df_without_Total.Total)
# Out:
# 127.39761797757144

# %%
df_2019 = df.loc[(df.Year == 2019)]

# %%
df_2019.sort_values(by=['Per Capita'],ascending=False).head(20)
# Out:
#                          Country ISO 3166-1 alpha-3  ...      Other  Per Capita
# 43739                      Qatar                QAT  ...        NaN   38.609507
# 13499                  Curaï¿½ao                CUW  ...        NaN   31.793396
# 38069              New Caledonia                NCL  ...        NaN   29.890724
# 55349        Trinidad and Tobago                TTO  ...        NaN   27.143098
# 28619                     Kuwait                KWT  ...        NaN   25.559764
# 8099           Brunei Darussalam                BRN  ...        NaN   20.976235
# 4319                     Bahrain                BHR  ...        NaN   20.932802
# 35369                   Mongolia                MNG  ...        NaN   20.313273
# 57509       United Arab Emirates                ARE  ...        NaN   19.516145
# 46979  Sint Maarten (Dutch part)                SXM  ...        NaN   17.769359
# 47789               Saudi Arabia                SAU  ...        NaN   16.987879
# ...
